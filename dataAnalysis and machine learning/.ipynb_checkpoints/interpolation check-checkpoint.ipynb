# %%
#the import packages
import requests
import pandas as pd
from pandas import json_normalize
import requests
import os
from pathlib import Path
from datetime import datetime, timezone,timedelta,time
from scipy import stats
import json
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
import sklearn.metrics as metrics

# %%
pd.set_option("display.max_columns", None)

# %%
def loadDataFromFile(file_name):
    script_dir = Path().resolve().parent

    data_folder = script_dir / 'dataAnalysis and machine learning'/'data'
    print(data_folder)
    data_folder.mkdir(exist_ok=True)
    
    file_path = data_folder / (file_name + ".json")
    
    if file_path.exists():
        df = pd.read_json(file_path)
        print(f"Loaded {len(df)} records from {file_path}")
        return df
    else:
        print(f"File {file_path} does not exist.")
        return None

# %%
userInputData = loadDataFromFile("UserPrevious experiments-preprocessed")
timeSeriesData_BIG = loadDataFromFile("Data:Previous experiments-preprocessed")
# Out:
# C:\Users\Andreas\Documents\PlatformIO\Projects\Diploma Project\dataAnalysis and machine learning\data
# Loaded 79 records from C:\Users\Andreas\Documents\PlatformIO\Projects\Diploma Project\dataAnalysis and machine learning\data\UserPrevious experiments-preprocessed.json
# C:\Users\Andreas\Documents\PlatformIO\Projects\Diploma Project\dataAnalysis and machine learning\data
# Loaded 199098 records from C:\Users\Andreas\Documents\PlatformIO\Projects\Diploma Project\dataAnalysis and machine learning\data\Data:Previous experiments-preprocessed.json

# %%
userInputData
# Out:
#              experimentState are-doors-opened are-people-inside  \
# 0   InsertingSourcePollutant               on              None
# 1   InsertingSourcePollutant               on              None
# 2   InsertingSourcePollutant               on              None
# 3   InsertingSourcePollutant               on              None
# 4   InsertingSourcePollutant               on              None
# ..                       ...              ...               ...
# 74  InsertingSourcePollutant               on              None
# 75  InsertingSourcePollutant               on              None
# 76  InsertingSourcePollutant               on              None
# 77  InsertingSourcePollutant               on              None
# 78  InsertingSourcePollutant               on              None
#
#    are-windows-opened  front-wall                item-used notes  \
# 0                None         0.9  Φαρμακευτικό αλκοόλ 95%
# 1                None         0.9  Φαρμακευτικό αλκοόλ 95%
# 2                None         0.4  Φαρμακευτικό αλκοόλ 95%
# 3                None         0.9  Φαρμακευτικό αλκοόλ 95%
# 4                None         1.4  Φαρμακευτικό αλκοόλ 95%
# ..                ...         ...                      ...   ...
# 74               None         NaN  Φαρμακευτικό αλκοόλ 95%
# 75               None         NaN  Φαρμακευτικό αλκοόλ 95%
# 76               None         NaN  Φαρμακευτικό αλκοόλ 95%
# 77               None         0.7  Φαρμακευτικό αλκοόλ 95%
# 78               None         0.6  Φαρμακευτικό αλκοόλ 95%
#
#                                                  room  side-right-wall  \
# 0     Κρεβατοκάμαρα id:1 Μ0.95 Α0.85 id:2 Μ0.95 Α1.55              NaN
# 1     Κρεβατοκάμαρα id:1 Μ0.95 Α0.85 id:2 Μ0.95 Α1.55              NaN
# 2     Κρεβατοκάμαρα id:1 Μ0.95 Α0.85 id:2 Μ0.95 Α1.55              NaN
# 3     Κρεβατοκάμαρα id:1 Μ0.95 Α0.85 id:2 Μ0.95 Α1.55              NaN
# 4     Κρεβατοκάμαρα id:1 Μ0.95 Α0.85 id:2 Μ0.95 Α1.55              NaN
# ..                                                ...              ...
# 74  Κρεβατοκάμαρα-Όλοι οι αισθητήρες μαζί Μ:0.80 ,...              NaN
# 75  Κρεβατοκάμαρα-Όλοι οι αισθητήρες μαζί Μ:0.80 ,...              1.0
# 76  Κρεβατοκάμαρα-Όλοι οι αισθητήρες μαζί Μ:0.80 ,...              NaN
# 77  Κρεβατοκάμαρα-Όλοι οι αισθητήρες μαζί Μ:0.80 ,...              0.9
# 78  Κρεβατοκάμαρα-Όλοι οι αισθητήρες μαζί Μ:0.80 ,...              NaN
#
#     back-wall  side-left-wall are-fans-on no-source-located  \
# 0         NaN             0.9        None              None
# 1         NaN             0.9        None              None
# 2         NaN             0.9        None              None
# 3         NaN             1.8        None              None
# 4         NaN             1.3        None              None
# ..        ...             ...         ...               ...
# 74        0.6             0.6        None              None
# 75        0.8             NaN        None              None
# 76        1.8             1.0        None              None
# 77        NaN             NaN        None              None
# 78        NaN             0.6        None              None
#
#    timestamp InsertingSource timestamp StartingExperiment  \
# 0        2025-07-01 16:09:41          2025-07-01 15:27:16
# 1        2025-07-02 15:59:29          2025-07-02 15:42:50
# 2        2025-07-03 12:34:32          2025-07-03 12:30:25
# 3        2025-07-03 15:53:07          2025-07-03 15:43:27
# 4        2025-07-09 19:19:19          2025-07-09 19:01:42
# ..                       ...                          ...
# 74       2025-08-26 13:09:30          2025-08-26 13:02:26
# 75       2025-08-26 13:42:02          2025-08-26 13:36:44
# 76       2025-08-26 16:49:11          2025-08-26 16:29:39
# 77       2025-08-26 18:25:06          2025-08-26 17:56:27
# 78       2025-08-26 18:46:41          2025-08-26 18:43:05
#
#    timestamp EndingExperiment  date of experiment  \
# 0         2025-07-01 16:14:44       1751328000000
# 1         2025-07-02 16:04:52       1751414400000
# 2         2025-07-03 12:45:31       1751500800000
# 3         2025-07-03 15:59:11       1751500800000
# 4         2025-07-09 19:27:50       1752019200000
# ..                        ...                 ...
# 74        2025-08-26 13:23:48       1756166400000
# 75        2025-08-26 13:53:04       1756166400000
# 76        2025-08-26 17:11:16       1756166400000
# 77        2025-08-26 18:33:20       1756166400000
# 78        2025-08-26 18:55:49       1756166400000
#
#     actual timestamp StartingExperiment  actual timestamp EndingExperiment  \
# 0                         1751383639000                      1751386484000
# 1                         1751470970000                      1751472292000
# 2                         1751545825000                      1751546731000
# 3                         1751557900000                      1751558351000
# 4                         1752087704000                      1752089270000
# ..                                  ...                                ...
# 74                        1756213347000                      1756214628000
# 75                        1756215406000                      1756216384000
# 76                        1756225781000                      1756228276000
# 77                        1756230988000                      1756233200000
# 78                        1756233787000                      1756234549000
#
#     time taken total  timestamp InsertingSource timedelta  \
# 0            2845000                              2543000
# 1            1322000                              1000000
# 2             906000                               248000
# 3             451000                                88000
# 4            1566000                              1056000
# ..               ...                                  ...
# 74           1281000                               424000
# 75            978000                               317000
# 76           2495000                              1171000
# 77           2212000                              1719000
# 78            762000                               215000
#
#     timestamp InsertingSource seconds  time taken after insertion
# 0                                2543                      302000
# 1                                1000                      322000
# 2                                 248                      658000
# 3                                  88                      363000
# 4                                1056                      510000
# ..                                ...                         ...
# 74                                424                      857000
# 75                                317                      661000
# 76                               1171                     1324000
# 77                               1719                      493000
# 78                                215                      547000
#
# [79 rows x 23 columns]

# %%
timeSeriesData_BIG
# Out:
#         keys  timestamp                          sensors         VOC  \
# 0          0          0  Id=1:BME680:breathVocEquivalent    1.476941
# 1          0          0  Id=2:BME680:breathVocEquivalent    1.430472
# 2          0       1000  Id=1:BME680:breathVocEquivalent    1.473184
# 3          0       1000  Id=2:BME680:breathVocEquivalent    1.434089
# 4          0       2000  Id=1:BME680:breathVocEquivalent    1.469428
# ...      ...        ...                              ...         ...
# 199093    78     761000  Id=2:BME680:breathVocEquivalent  513.575400
# 199094    78     761000  Id=0:BME680:breathVocEquivalent   25.242983
# 199095    78     762000  Id=1:BME680:breathVocEquivalent   81.105730
# 199096    78     762000  Id=2:BME680:breathVocEquivalent  513.575400
# 199097    78     762000  Id=0:BME680:breathVocEquivalent   23.198300
#
#         after_insertion  original_value  datetime_timestamp  seconds
# 0                 False           False       1751383639000        0
# 1                 False            True       1751383639000        0
# 2                 False           False       1751383640000        1
# 3                 False           False       1751383640000        1
# 4                 False            True       1751383641000        2
# ...                 ...             ...                 ...      ...
# 199093             True            True       1756234548000      761
# 199094             True           False       1756234548000      761
# 199095             True           False       1756234549000      762
# 199096             True           False       1756234549000      762
# 199097             True            True       1756234549000      762
#
# [199098 rows x 8 columns]

# %%
# Convert back to timedelta
timeSeriesData_BIG['timestamp'] = pd.to_timedelta(timeSeriesData_BIG['timestamp'], unit='ms')

# Convert back to datetime

timeSeriesData_BIG ["datetime_timestamp"]= timeSeriesData_BIG['datetime_timestamp'].transform(
    lambda x: pd.to_datetime(x, unit='ms')
)
# Split back into dict
dict_of_timeseries = {k: v.drop(columns="keys").reset_index(drop=True) 
             for k, v in timeSeriesData_BIG.groupby("keys")}

# %%
dict_of_timeseries[0]
# Out:
#            timestamp                          sensors       VOC  \
# 0    0 days 00:00:00  Id=1:BME680:breathVocEquivalent  1.476941
# 1    0 days 00:00:00  Id=2:BME680:breathVocEquivalent  1.430472
# 2    0 days 00:00:01  Id=1:BME680:breathVocEquivalent  1.473184
# 3    0 days 00:00:01  Id=2:BME680:breathVocEquivalent  1.434089
# 4    0 days 00:00:02  Id=1:BME680:breathVocEquivalent  1.469428
# ...              ...                              ...       ...
# 5687 0 days 00:47:23  Id=2:BME680:breathVocEquivalent  9.453519
# 5688 0 days 00:47:24  Id=1:BME680:breathVocEquivalent  5.150744
# 5689 0 days 00:47:24  Id=2:BME680:breathVocEquivalent  9.469537
# 5690 0 days 00:47:25  Id=1:BME680:breathVocEquivalent  5.150744
# 5691 0 days 00:47:25  Id=2:BME680:breathVocEquivalent  9.469537
#
#       after_insertion  original_value  datetime_timestamp  seconds
# 0               False           False 2025-07-01 15:27:19        0
# 1               False            True 2025-07-01 15:27:19        0
# 2               False           False 2025-07-01 15:27:20        1
# 3               False           False 2025-07-01 15:27:20        1
# 4               False            True 2025-07-01 15:27:21        2
# ...               ...             ...                 ...      ...
# 5687             True           False 2025-07-01 16:14:42     2843
# 5688             True           False 2025-07-01 16:14:43     2844
# 5689             True            True 2025-07-01 16:14:43     2844
# 5690             True           False 2025-07-01 16:14:44     2845
# 5691             True           False 2025-07-01 16:14:44     2845
#
# [5692 rows x 7 columns]

# %%
columns_datetime= [
       'date of experiment', 'actual timestamp StartingExperiment',
       'actual timestamp EndingExperiment', ]
columns_timedelta = ['time taken total',
       'timestamp InsertingSource timedelta',
       'time taken after insertion']

userInputData.loc[:,columns_datetime] = userInputData.loc[:,columns_datetime].apply(lambda x:pd.to_datetime(x, unit='ms'))
userInputData.loc[:,columns_timedelta] = userInputData.loc[:,columns_timedelta].apply(lambda x:pd.to_timedelta(x, unit='ms'))

# %%
#remove all 
timeSeriesData_BIG_check_Interpolation = timeSeriesData_BIG.copy()
print(timeSeriesData_BIG_check_Interpolation.columns)

timeSeriesData_BIG_check_Interpolation["VOC given real values"] = timeSeriesData_BIG_check_Interpolation["VOC"]
timeSeriesData_BIG_check_Interpolation["VOC given real values"] = timeSeriesData_BIG_check_Interpolation["VOC given real values"].mask(timeSeriesData_BIG_check_Interpolation["original_value"]==False)
#timeSeriesData_BIG_check_Interpolation["points to check interpolation"] = timeSeriesData_BIG_check_Interpolation["VOC"]
#timeSeriesData_BIG_check_Interpolation["points to check interpolation"] = timeSeriesData_BIG_check_Interpolation["points to check interpolation"].mask(timeSeriesData_BIG_check_Interpolation["kept to test interpolation"] == False)
timeSeriesData_BIG_check_Interpolation["original_value_cum_sum"] = timeSeriesData_BIG_check_Interpolation.groupby(["keys","sensors"])["original_value"].transform("cumsum")
#make every second appear of a true given value null also 
#mask = (timeSeriesData_BIG_check_Interpolation["original_value"] == True) & (timeSeriesData_BIG_check_Interpolation["original_value_cum_sum"] % 2 == 0)
#timeSeriesData_BIG_check_Interpolation.loc[:,"kept to test interpolation"] =timeSeriesData_BIG_check_Interpolation.apply(lambda x: True if ((x["original_value"] == True) & (x["original_value_cum_sum"] % 2 == 1)) else False,axis=1)
timeSeriesData_BIG_check_Interpolation.head(20)
# Out:
# Index(['keys', 'timestamp', 'sensors', 'VOC', 'after_insertion',
#        'original_value', 'datetime_timestamp', 'seconds'],
#       dtype='object')
#     keys       timestamp                          sensors       VOC  \
# 0      0 0 days 00:00:00  Id=1:BME680:breathVocEquivalent  1.476941
# 1      0 0 days 00:00:00  Id=2:BME680:breathVocEquivalent  1.430472
# 2      0 0 days 00:00:01  Id=1:BME680:breathVocEquivalent  1.473184
# 3      0 0 days 00:00:01  Id=2:BME680:breathVocEquivalent  1.434089
# 4      0 0 days 00:00:02  Id=1:BME680:breathVocEquivalent  1.469428
# 5      0 0 days 00:00:02  Id=2:BME680:breathVocEquivalent  1.437705
# 6      0 0 days 00:00:03  Id=1:BME680:breathVocEquivalent  1.471700
# 7      0 0 days 00:00:03  Id=2:BME680:breathVocEquivalent  1.441322
# 8      0 0 days 00:00:04  Id=1:BME680:breathVocEquivalent  1.473971
# 9      0 0 days 00:00:04  Id=2:BME680:breathVocEquivalent  1.444173
# 10     0 0 days 00:00:05  Id=1:BME680:breathVocEquivalent  1.476243
# 11     0 0 days 00:00:05  Id=2:BME680:breathVocEquivalent  1.447023
# 12     0 0 days 00:00:06  Id=1:BME680:breathVocEquivalent  1.475396
# 13     0 0 days 00:00:06  Id=2:BME680:breathVocEquivalent  1.449874
# 14     0 0 days 00:00:07  Id=1:BME680:breathVocEquivalent  1.474548
# 15     0 0 days 00:00:07  Id=2:BME680:breathVocEquivalent  1.454506
# 16     0 0 days 00:00:08  Id=1:BME680:breathVocEquivalent  1.473701
# 17     0 0 days 00:00:08  Id=2:BME680:breathVocEquivalent  1.459138
# 18     0 0 days 00:00:09  Id=1:BME680:breathVocEquivalent  1.477970
# 19     0 0 days 00:00:09  Id=2:BME680:breathVocEquivalent  1.463770
#
#     after_insertion  original_value  datetime_timestamp  seconds  \
# 0             False           False 2025-07-01 15:27:19        0
# 1             False            True 2025-07-01 15:27:19        0
# 2             False           False 2025-07-01 15:27:20        1
# 3             False           False 2025-07-01 15:27:20        1
# 4             False            True 2025-07-01 15:27:21        2
# 5             False           False 2025-07-01 15:27:21        2
# 6             False           False 2025-07-01 15:27:22        3
# 7             False            True 2025-07-01 15:27:22        3
# 8             False           False 2025-07-01 15:27:23        4
# 9             False           False 2025-07-01 15:27:23        4
# 10            False            True 2025-07-01 15:27:24        5
# 11            False           False 2025-07-01 15:27:24        5
# 12            False           False 2025-07-01 15:27:25        6
# 13            False            True 2025-07-01 15:27:25        6
# 14            False           False 2025-07-01 15:27:26        7
# 15            False           False 2025-07-01 15:27:26        7
# 16            False            True 2025-07-01 15:27:27        8
# 17            False           False 2025-07-01 15:27:27        8
# 18            False           False 2025-07-01 15:27:28        9
# 19            False            True 2025-07-01 15:27:28        9
#
#     VOC given real values  original_value_cum_sum
# 0                     NaN                       0
# 1                1.430472                       1
# 2                     NaN                       0
# 3                     NaN                       1
# 4                1.469428                       1
# 5                     NaN                       1
# 6                     NaN                       1
# 7                1.441322                       2
# 8                     NaN                       1
# 9                     NaN                       2
# 10               1.476243                       2
# 11                    NaN                       2
# 12                    NaN                       2
# 13               1.449874                       3
# 14                    NaN                       2
# 15                    NaN                       3
# 16               1.473701                       3
# 17                    NaN                       3
# 18                    NaN                       3
# 19               1.463770                       4

# %%
# Split back into dict
dict_of_timeseries_inter = {k: v.drop(columns="keys").reset_index(drop=True) 
             for k, v in timeSeriesData_BIG_check_Interpolation.groupby("keys")}

# %%
dict_of_timeseries_inter[2]
# Out:
#            timestamp                          sensors        VOC  \
# 0    0 days 00:00:00  Id=1:BME680:breathVocEquivalent   2.110552
# 1    0 days 00:00:00  Id=2:BME680:breathVocEquivalent   4.323138
# 2    0 days 00:00:01  Id=1:BME680:breathVocEquivalent   2.110852
# 3    0 days 00:00:01  Id=2:BME680:breathVocEquivalent   4.321439
# 4    0 days 00:00:02  Id=1:BME680:breathVocEquivalent   2.111153
# ...              ...                              ...        ...
# 1809 0 days 00:15:04  Id=2:BME680:breathVocEquivalent  29.074413
# 1810 0 days 00:15:05  Id=1:BME680:breathVocEquivalent   2.092415
# 1811 0 days 00:15:05  Id=2:BME680:breathVocEquivalent  29.758007
# 1812 0 days 00:15:06  Id=1:BME680:breathVocEquivalent   2.099104
# 1813 0 days 00:15:06  Id=2:BME680:breathVocEquivalent  30.441600
#
#       after_insertion  original_value  datetime_timestamp  seconds  \
# 0               False            True 2025-07-03 12:30:25        0
# 1               False            True 2025-07-03 12:30:25        0
# 2               False           False 2025-07-03 12:30:26        1
# 3               False           False 2025-07-03 12:30:26        1
# 4               False           False 2025-07-03 12:30:27        2
# ...               ...             ...                 ...      ...
# 1809             True           False 2025-07-03 12:45:29      904
# 1810             True           False 2025-07-03 12:45:30      905
# 1811             True           False 2025-07-03 12:45:30      905
# 1812             True            True 2025-07-03 12:45:31      906
# 1813             True            True 2025-07-03 12:45:31      906
#
#       VOC given real values  original_value_cum_sum
# 0                  2.110552                       1
# 1                  4.323138                       1
# 2                       NaN                       1
# 3                       NaN                       1
# 4                       NaN                       1
# ...                     ...                     ...
# 1809                    NaN                     302
# 1810                    NaN                     302
# 1811                    NaN                     302
# 1812               2.099104                     303
# 1813              30.441600                     303
#
# [1814 rows x 9 columns]

# %%
def insertColumnsTointerpolation_differences(interpolation_differences,method):
    columns= []
    sensors_names = ["Id=0:BME680:breathVocEquivalent","Id=1:BME680:breathVocEquivalent","Id=2:BME680:breathVocEquivalent"]
    columns.extend(["MSE-" + x +"-"+method for x in sensors_names])
    columns.extend(["MAE-" + x +"-"+method for x in sensors_names])
  #  columns.extend(["R2-" + x +"-"+method for x in sensors_names])
    for column in columns:
        interpolation_differences[column] = np.nan
    return interpolation_differences

# %%
def checkInterpolationMethod(dict_of_timeseries_inter,interpolation_differences,method):
    insertColumnsTointerpolation_differences(interpolation_differences,method)
    #print(interpolation_differences)

    for index, row in userInputData.iterrows():
        
        experiment_df = dict_of_timeseries_inter[index]
        #print(experiment_df)
        sensors = experiment_df["sensors"].unique()
        target_column = "VOC-" +method
        experiment_df[target_column] = experiment_df.apply(lambda x:x["VOC given real values"] if (x["original_value_cum_sum"]% 2 == 0) else np.nan,axis=1)
        experiment_df    
        for sensor in sensors:
            mask = (experiment_df["sensors"] == sensor)
          #  print(experiment_df.loc[mask,:].shape)
            experiment_df.loc[mask,target_column] = experiment_df.loc[mask,target_column].interpolate(method = method)
          #  print(experiment_df.loc[mask,target_column].shape)
         #   print(f"na are {experiment_df.isna().sum()}")
            dropped_df = experiment_df.loc[mask,:].dropna()
          #  print(dropped_df.shape)
            mae = metrics.mean_absolute_error(dropped_df.loc[mask,"VOC given real values"], dropped_df.loc[mask,target_column])
          #  print("a")
            column_to_save = "MAE-"+sensor +"-"+method
            interpolation_differences.at[index,column_to_save] = mae
            mse = metrics.mean_squared_error(dropped_df.loc[mask,"VOC given real values"], dropped_df.loc[mask,target_column])
          #  print("a")
            column_to_save = "MSE-"+sensor +"-"+method
            interpolation_differences.at[index,column_to_save] = mse
            
        dict_of_timeseries_inter[index] = experiment_df
    return dict_of_timeseries_inter

# %%
# Split back into dict
dict_of_timeseries_inter = {k: v.drop(columns="keys").reset_index(drop=True) 
             for k, v in timeSeriesData_BIG_check_Interpolation.groupby("keys")}
interpolation_differences = pd.DataFrame(index = np.arange(userInputData.shape[0]))
dict_of_timeseries_inter = checkInterpolationMethod(dict_of_timeseries_inter,interpolation_differences,"linear")
dict_of_timeseries_inter = checkInterpolationMethod(dict_of_timeseries_inter,interpolation_differences,"cubicspline")

# %%
interpolation_differences
# Out:
#     MAE-Id=0:BME680:breathVocEquivalent-linear  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 74                                    0.015308
# 75                                    0.019506
# 76                                    0.049764
# 77                                    0.009829
# 78                                    0.209005
#
#     MAE-Id=1:BME680:breathVocEquivalent-linear  \
# 0                                     0.002923
# 1                                     0.001482
# 2                                     0.004684
# 3                                     0.002175
# 4                                     0.001111
# ..                                         ...
# 74                                    0.003926
# 75                                    0.007143
# 76                                    0.090094
# 77                                    0.014347
# 78                                    2.683406
#
#     MAE-Id=2:BME680:breathVocEquivalent-linear  \
# 0                                     0.010411
# 1                                     0.001301
# 2                                     0.029709
# 3                                     0.039105
# 4                                     0.002077
# ..                                         ...
# 74                                    0.003829
# 75                                    0.004263
# 76                                    0.200152
# 77                                    0.012508
# 78                                    6.816408
#
#     MSE-Id=1:BME680:breathVocEquivalent-linear  \
# 0                                     0.002923
# 1                                     0.001482
# 2                                     0.004684
# 3                                     0.002175
# 4                                     0.001111
# ..                                         ...
# 74                                    0.003926
# 75                                    0.007143
# 76                                    0.090094
# 77                                    0.014347
# 78                                    2.683406
#
#     MSE-Id=2:BME680:breathVocEquivalent-linear  \
# 0                                     0.010411
# 1                                     0.001301
# 2                                     0.029709
# 3                                     0.039105
# 4                                     0.002077
# ..                                         ...
# 74                                    0.003829
# 75                                    0.004263
# 76                                    0.200152
# 77                                    0.012508
# 78                                    6.816408
#
#     MSE-Id=0:BME680:breathVocEquivalent-linear  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 74                                    0.015308
# 75                                    0.019506
# 76                                    0.049764
# 77                                    0.009829
# 78                                    0.209005
#
#     MAE-Id=0:BME680:breathVocEquivalent-cubicspline  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 74                                         0.014041
# 75                                         0.018697
# 76                                         0.035156
# 77                                         0.010048
# 78                                         0.211031
#
#     MAE-Id=1:BME680:breathVocEquivalent-cubicspline  \
# 0                                          0.002947
# 1                                          0.001366
# 2                                          0.004957
# 3                                          0.002440
# 4                                          0.001104
# ..                                              ...
# 74                                         0.003939
# 75                                         0.006718
# 76                                         0.043476
# 77                                         0.013734
# 78                                         1.467522
#
#     MAE-Id=2:BME680:breathVocEquivalent-cubicspline  \
# 0                                          0.011062
# 1                                          0.001302
# 2                                          0.024679
# 3                                          0.036816
# 4                                          0.002271
# ..                                              ...
# 74                                         0.003591
# 75                                         0.003722
# 76                                         0.110793
# 77                                         0.012830
# 78                                         6.082774
#
#     MSE-Id=1:BME680:breathVocEquivalent-cubicspline  \
# 0                                          0.002947
# 1                                          0.001366
# 2                                          0.004957
# 3                                          0.002440
# 4                                          0.001104
# ..                                              ...
# 74                                         0.003939
# 75                                         0.006718
# 76                                         0.043476
# 77                                         0.013734
# 78                                         1.467522
#
#     MSE-Id=2:BME680:breathVocEquivalent-cubicspline  \
# 0                                          0.011062
# 1                                          0.001302
# 2                                          0.024679
# 3                                          0.036816
# 4                                          0.002271
# ..                                              ...
# 74                                         0.003591
# 75                                         0.003722
# 76                                         0.110793
# 77                                         0.012830
# 78                                         6.082774
#
#     MSE-Id=0:BME680:breathVocEquivalent-cubicspline
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 74                                         0.014041
# 75                                         0.018697
# 76                                         0.035156
# 77                                         0.010048
# 78                                         0.211031
#
# [79 rows x 12 columns]

# %%
interpolation_differences.mean()
# Out:
# MAE-Id=0:BME680:breathVocEquivalent-linear         0.029408
# MAE-Id=1:BME680:breathVocEquivalent-linear         0.047642
# MAE-Id=2:BME680:breathVocEquivalent-linear         0.184499
# MSE-Id=1:BME680:breathVocEquivalent-linear         0.047642
# MSE-Id=2:BME680:breathVocEquivalent-linear         0.184499
# MSE-Id=0:BME680:breathVocEquivalent-linear         0.029408
# MAE-Id=0:BME680:breathVocEquivalent-cubicspline    0.026310
# MAE-Id=1:BME680:breathVocEquivalent-cubicspline    0.031558
# MAE-Id=2:BME680:breathVocEquivalent-cubicspline    0.185519
# MSE-Id=1:BME680:breathVocEquivalent-cubicspline    0.031558
# MSE-Id=2:BME680:breathVocEquivalent-cubicspline    0.185519
# MSE-Id=0:BME680:breathVocEquivalent-cubicspline    0.026310
# dtype: float64

# %%
sns.scatterplot(interpolation_differences)
# Out:
# <Axes: >
