# %%
#the pip commands to be used here

# %pip install requests
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 1.1 MB/s eta 0:00:001.2 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 1.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 1.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 858.9 kB/s eta 0:00:001m588.9 kB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 kB 1.6 MB/s eta 0:00:001.4 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#the import packages
import requests
import pandas as pd
from pandas import json_normalize
import requests
import os
import json

# %%
#some constants to be used
base_url = "http://192.168.43.25:8080/dataAnalysisEndpoints/"
def create_url(endpoint):
    return base_url + endpoint

# %%
#get the user Input data
# Send request
url = create_url('getAllUserInputsExperimentState')
print(url)
response = requests.get(url)

# Check response status
if response.status_code == 200:
    userInputData = response.json()
    print(f"Received {len(userInputData)} records.")
else:
    print(f"Error: {userInputData.status_code}")
# Out:
# http://192.168.43.25:8080/dataAnalysisEndpoints/getAllUserInputsExperimentState
# Received 16 records.

# %%
df_userInputData = pd.DataFrame(userInputData)

# %%
df_userInputData = json_normalize(df,record_path='details')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df_userInputData = json_normalize(df,record_path='details')
#
# NameError: name 'json_normalize' is not defined
