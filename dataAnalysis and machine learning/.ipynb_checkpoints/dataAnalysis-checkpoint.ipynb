# %%
#the pip commands to be used here

# %pip install requests
# %pip install pandas
# Out:
# Requirement already satisfied: requests in c:\python311\lib\site-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\python311\lib\site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python311\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python311\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python311\lib\site-packages (from requests) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (C:\Python311\Lib\site-packages)
# Requirement already satisfied: pandas in c:\python311\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\andreas\appdata\roaming\python\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\python311\lib\site-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in c:\users\andreas\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (C:\Python311\Lib\site-packages)

# %%
#the import packages
import requests
import pandas as pd
from pandas import json_normalize
import requests
import os
import json

# %%
#some constants to be used
base_url = "http://192.168.43.25:8080/dataAnalysisEndpoints/"
def create_url(endpoint):
    return base_url + endpoint
def getData(url):
    response = requests.get(url)

    # Check response status
    if response.status_code == 200:
        data = response.json()
        print(f"Received {len(data)} records.")
        return data
    else:
        print(f"Error: {response.status_code}")

# %%
#get the user Input data
# Send request
url = create_url('getAllUserInputsExperimentState')
df_userInputData = pd.DataFrame.from_dict(getData(url))
# Out:
# Received 31 records.

# %%
details_df = df_userInputData["details"].apply(pd.Series)

# Then join with the original DataFrame (drop the nested 'details' if desired)
df_userInputData = pd.concat([df_userInputData.drop(columns=["details"]), details_df], axis=1)

# %%
df_userInputData
# Out:
#                                      _id           experimentState  \
# 0   {'$oid': '6849ace703a598ff63a65bf8'}        StartingExperiment
# 1   {'$oid': '6849aefb03a598ff63a6667f'}  InsertingSourcePollutant
# 2   {'$oid': '6849b77503a598ff63a68c90'}   RemovingSourcePollutant
# 3   {'$oid': '6849ba8d03a598ff63a69cd3'}  InsertingSourcePollutant
# 4   {'$oid': '6849c2dc03a598ff63a6c299'}   RemovingSourcePollutant
# 5   {'$oid': '6849c5ab03a598ff63a6ce5f'}  InsertingSourcePollutant
# 6   {'$oid': '6849cdc303a598ff63a6f7a7'}   RemovingSourcePollutant
# 7   {'$oid': '6849d10203a598ff63a7085e'}  InsertingSourcePollutant
# 8   {'$oid': '6849d99703a598ff63a73445'}   RemovingSourcePollutant
# 9   {'$oid': '6849ddff03a598ff63a74a63'}  InsertingSourcePollutant
# 10  {'$oid': '6849e69b03a598ff63a775e6'}   RemovingSourcePollutant
# 11  {'$oid': '6849e97d03a598ff63a784c9'}  InsertingSourcePollutant
# 12  {'$oid': '6849f13303a598ff63a7abcf'}   RemovingSourcePollutant
# 13  {'$oid': '6849f4badebb08fa46dec567'}  InsertingSourcePollutant
# 14  {'$oid': '6849fcccac7f900b045b4d6f'}   RemovingSourcePollutant
# 15  {'$oid': '684a01ccac7f900b045b66bf'}  InsertingSourcePollutant
# 16  {'$oid': '684a0aaa031215f54b6f4889'}   RemovingSourcePollutant
# 17  {'$oid': '684a0ee0031215f54b6f5d2d'}  InsertingSourcePollutant
# 18  {'$oid': '684af7b78ad2cd52978f4af4'}        StartingExperiment
# 19  {'$oid': '684afcdf8ad2cd52978f638d'}  InsertingSourcePollutant
# 20  {'$oid': '684b0c908ad2cd52978f8641'}   RemovingSourcePollutant
# 21  {'$oid': '684b12168ad2cd52978f92ea'}  InsertingSourcePollutant
# 22  {'$oid': '684b1be48ad2cd52978fc054'}   RemovingSourcePollutant
# 23  {'$oid': '684b21cb8ad2cd52978fdeca'}  InsertingSourcePollutant
# 24  {'$oid': '684b2af0c4ba872d6a031472'}   RemovingSourcePollutant
# 25  {'$oid': '684b3582440322b264da457e'}  InsertingSourcePollutant
# 26  {'$oid': '684b3ebc99afe3f757053c92'}   RemovingSourcePollutant
# 27  {'$oid': '684b4244c3e31ce70438ae27'}  InsertingSourcePollutant
# 28  {'$oid': '684b4b79b6e12fa45685e02c'}   RemovingSourcePollutant
# 29  {'$oid': '684b4eabb6e12fa45685f06c'}  InsertingSourcePollutant
# 30  {'$oid': '684b56a2b6e12fa45686189c'}   RemovingSourcePollutant
#
#                    timestamp userInputCategory   0 are-doors-opened  \
# 0   {'$date': 1749658855857}   ExperimentState NaN              NaN
# 1   {'$date': 1749659387774}   ExperimentState NaN               on
# 2   {'$date': 1749661557509}   ExperimentState NaN              NaN
# 3   {'$date': 1749662349567}   ExperimentState NaN               on
# 4   {'$date': 1749664476491}   ExperimentState NaN              NaN
# 5   {'$date': 1749665195504}   ExperimentState NaN               on
# 6   {'$date': 1749667267330}   ExperimentState NaN              NaN
# 7   {'$date': 1749668098365}   ExperimentState NaN               on
# 8   {'$date': 1749670295490}   ExperimentState NaN              NaN
# 9   {'$date': 1749671423708}   ExperimentState NaN               on
# 10  {'$date': 1749673627254}   ExperimentState NaN              NaN
# 11  {'$date': 1749674365114}   ExperimentState NaN               on
# 12  {'$date': 1749676339982}   ExperimentState NaN              NaN
# 13  {'$date': 1749677242338}   ExperimentState NaN               on
# 14  {'$date': 1749679308742}   ExperimentState NaN              NaN
# 15  {'$date': 1749680588949}   ExperimentState NaN               on
# 16  {'$date': 1749682858533}   ExperimentState NaN              NaN
# 17  {'$date': 1749683936838}   ExperimentState NaN               on
# 18  {'$date': 1749743543693}   ExperimentState NaN              NaN
# 19  {'$date': 1749744863788}   ExperimentState NaN               on
# 20  {'$date': 1749748880682}   ExperimentState NaN              NaN
# 21  {'$date': 1749750294045}   ExperimentState NaN               on
# 22  {'$date': 1749752804880}   ExperimentState NaN              NaN
# 23  {'$date': 1749754315351}   ExperimentState NaN               on
# 24  {'$date': 1749756656094}   ExperimentState NaN              NaN
# 25  {'$date': 1749759362051}   ExperimentState NaN               on
# 26  {'$date': 1749761724467}   ExperimentState NaN              NaN
# 27  {'$date': 1749762628817}   ExperimentState NaN               on
# 28  {'$date': 1749764985584}   ExperimentState NaN              NaN
# 29  {'$date': 1749765803734}   ExperimentState NaN               on
# 30  {'$date': 1749767842431}   ExperimentState NaN              NaN
#
#    are-people-inside are-windows-opened front-wall                item-used  \
# 0                NaN                NaN        NaN                      NaN
# 1                 on                 on        1.5      φαρμακευτική λοτιόν
# 2                NaN                NaN        NaN                      NaN
# 3                 on                 on        1.5      Φαρμακευτικό αλκοόλ
# 4                NaN                NaN        NaN                      NaN
# 5                 on                 on        1.5      Φαρμακευτικό αλκοόλ
# 6                NaN                NaN        NaN                      NaN
# 7                 on                 on        1.5      Φαρμακευτικό αλκοόλ
# 8                NaN                NaN        NaN                      NaN
# 9                NaN                 on        1.5      Φαρμακευτικό αλκοόλ
# 10               NaN                NaN        NaN                      NaN
# 11               NaN                 on        1.5      Φαρμακευτικό αλκοόλ
# 12               NaN                NaN        NaN                      NaN
# 13               NaN                 on        1.5      Φαρμακευτικό αλκοόλ
# 14               NaN                NaN        NaN                      NaN
# 15                on                 on        1.5      Φαρμακευτικό αλκοόλ
# 16               NaN                NaN        NaN                      NaN
# 17                on                 on        1.5      Φαρμακευτικό αλκοόλ
# 18               NaN                NaN        NaN                      NaN
# 19                on                 on        1.5  Φαρμακευτικό αλκοόλ 95%
# 20               NaN                NaN        NaN                      NaN
# 21                on                 on        1.5  Φαρμακευτικό αλκοόλ 95%
# 22               NaN                NaN        NaN                      NaN
# 23                on                 on        1.5  Φαρμακευτικό αλκοόλ 95%
# 24               NaN                NaN        NaN                      NaN
# 25                on                 on        1.5  Φαρμακευτικό αλκοόλ 95%
# 26               NaN                NaN        NaN                      NaN
# 27                on                 on        1.5  Φαρμακευτικό αλκοόλ 95%
# 28               NaN                NaN        NaN                      NaN
# 29                on                 on        1.5  φαρμακευτική λοτιόν 93%
# 30               NaN                NaN        NaN                      NaN
#
#    notes pollutant-type                                      quantity-used  \
# 0    NaN            NaN                                                NaN
# 1                   VOC                           δύο κουταλιές της σούπας
# 2    NaN            NaN                                                NaN
# 3                   VOC                          τρεις κουταλιά της σούπας
# 4    NaN            NaN                                                NaN
# 5                   VOC                          τρεις κουταλιά της σούπας
# 6    NaN            NaN                                                NaN
# 7                   VOC                          τρεις κουταλιά της σούπας
# 8    NaN            NaN                                                NaN
# 9                   VOC                          τρεις κουταλιά της σούπας
# 10   NaN            NaN                                                NaN
# 11                  VOC  τρεις κουταλιά της σούπας+ ότι δεν έχει εξατμι...
# 12   NaN            NaN                                                NaN
# 13                  VOC  τρεις κουταλιά της σούπας+ ότι δεν έχει εξατμι...
# 14   NaN            NaN                                                NaN
# 15                  VOC  τρεις κουταλιά της σούπας+ ότι δεν έχει εξατμι...
# 16   NaN            NaN                                                NaN
# 17                  VOC                            μία κουταλιά της σούπας
# 18   NaN            NaN                                                NaN
# 19                  VOC                            μία κουταλιά της σούπας
# 20   NaN            NaN                                                NaN
# 21                  VOC                                      13 ml περιπου
# 22   NaN            NaN                                                NaN
# 23                  VOC                                              17 ml
# 24   NaN            NaN                                                NaN
# 25                  VOC                                              10 ml
# 26   NaN            NaN                                                NaN
# 27                  VOC                                                 13
# 28   NaN            NaN                                                NaN
# 29                  VOC                                              35 ml
# 30   NaN            NaN                                                NaN
#
#       room side-right-wall
# 0      NaN             NaN
# 1   Σαλόνι             1.7
# 2      NaN             NaN
# 3   Σαλόνι             1.7
# 4      NaN             NaN
# 5   Σαλόνι             1.7
# 6      NaN             NaN
# 7   Σαλόνι             1.7
# 8      NaN             NaN
# 9   Σαλόνι             1.7
# 10     NaN             NaN
# 11  Σαλόνι             1.7
# 12     NaN             NaN
# 13  Σαλόνι             1.7
# 14     NaN             NaN
# 15  Σαλόνι             1.5
# 16     NaN             NaN
# 17  Σαλόνι             1.5
# 18     NaN             NaN
# 19  Σαλόνι             1.5
# 20     NaN             NaN
# 21  σαλονι             1.5
# 22     NaN             NaN
# 23  Σαλόνι             1.7
# 24     NaN             NaN
# 25  Σαλόνι             1.7
# 26     NaN             NaN
# 27  Σαλόνι             1.7
# 28     NaN             NaN
# 29  Σαλόνι             1.7
# 30     NaN             NaN

# %%
df_userInputData = df_userInputData.drop(columns=['0'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df_userInputData = df_userInputData.drop(columns=['0'])
#
# File C:\Python311\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File C:\Python311\Lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File C:\Python311\Lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File C:\Python311\Lib\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['0'] not found in axis"

# %%
# Convert epoch (assumes seconds) to datetime in local time
df_userInputData["epoch_ms"] = df_userInputData["timestamp"].apply(lambda x: x["$date"])
df_userInputData["timestamp_local"] = pd.to_datetime(df_userInputData["epoch_ms"], unit="ms").dt.tz_localize("UTC").dt.tz_convert("Europe/Athens")
df_userInputData.drop(columns = ["timestamp"])
# Out:
#                                      _id           experimentState  \
# 0   {'$oid': '6849ace703a598ff63a65bf8'}        StartingExperiment
# 1   {'$oid': '6849aefb03a598ff63a6667f'}  InsertingSourcePollutant
# 2   {'$oid': '6849b77503a598ff63a68c90'}   RemovingSourcePollutant
# 3   {'$oid': '6849ba8d03a598ff63a69cd3'}  InsertingSourcePollutant
# 4   {'$oid': '6849c2dc03a598ff63a6c299'}   RemovingSourcePollutant
# 5   {'$oid': '6849c5ab03a598ff63a6ce5f'}  InsertingSourcePollutant
# 6   {'$oid': '6849cdc303a598ff63a6f7a7'}   RemovingSourcePollutant
# 7   {'$oid': '6849d10203a598ff63a7085e'}  InsertingSourcePollutant
# 8   {'$oid': '6849d99703a598ff63a73445'}   RemovingSourcePollutant
# 9   {'$oid': '6849ddff03a598ff63a74a63'}  InsertingSourcePollutant
# 10  {'$oid': '6849e69b03a598ff63a775e6'}   RemovingSourcePollutant
# 11  {'$oid': '6849e97d03a598ff63a784c9'}  InsertingSourcePollutant
# 12  {'$oid': '6849f13303a598ff63a7abcf'}   RemovingSourcePollutant
# 13  {'$oid': '6849f4badebb08fa46dec567'}  InsertingSourcePollutant
# 14  {'$oid': '6849fcccac7f900b045b4d6f'}   RemovingSourcePollutant
# 15  {'$oid': '684a01ccac7f900b045b66bf'}  InsertingSourcePollutant
# 16  {'$oid': '684a0aaa031215f54b6f4889'}   RemovingSourcePollutant
# 17  {'$oid': '684a0ee0031215f54b6f5d2d'}  InsertingSourcePollutant
# 18  {'$oid': '684af7b78ad2cd52978f4af4'}        StartingExperiment
# 19  {'$oid': '684afcdf8ad2cd52978f638d'}  InsertingSourcePollutant
# 20  {'$oid': '684b0c908ad2cd52978f8641'}   RemovingSourcePollutant
# 21  {'$oid': '684b12168ad2cd52978f92ea'}  InsertingSourcePollutant
# 22  {'$oid': '684b1be48ad2cd52978fc054'}   RemovingSourcePollutant
# 23  {'$oid': '684b21cb8ad2cd52978fdeca'}  InsertingSourcePollutant
# 24  {'$oid': '684b2af0c4ba872d6a031472'}   RemovingSourcePollutant
# 25  {'$oid': '684b3582440322b264da457e'}  InsertingSourcePollutant
# 26  {'$oid': '684b3ebc99afe3f757053c92'}   RemovingSourcePollutant
# 27  {'$oid': '684b4244c3e31ce70438ae27'}  InsertingSourcePollutant
# 28  {'$oid': '684b4b79b6e12fa45685e02c'}   RemovingSourcePollutant
# 29  {'$oid': '684b4eabb6e12fa45685f06c'}  InsertingSourcePollutant
# 30  {'$oid': '684b56a2b6e12fa45686189c'}   RemovingSourcePollutant
#
#    userInputCategory   0 are-doors-opened are-people-inside  \
# 0    ExperimentState NaN              NaN               NaN
# 1    ExperimentState NaN               on                on
# 2    ExperimentState NaN              NaN               NaN
# 3    ExperimentState NaN               on                on
# 4    ExperimentState NaN              NaN               NaN
# 5    ExperimentState NaN               on                on
# 6    ExperimentState NaN              NaN               NaN
# 7    ExperimentState NaN               on                on
# 8    ExperimentState NaN              NaN               NaN
# 9    ExperimentState NaN               on               NaN
# 10   ExperimentState NaN              NaN               NaN
# 11   ExperimentState NaN               on               NaN
# 12   ExperimentState NaN              NaN               NaN
# 13   ExperimentState NaN               on               NaN
# 14   ExperimentState NaN              NaN               NaN
# 15   ExperimentState NaN               on                on
# 16   ExperimentState NaN              NaN               NaN
# 17   ExperimentState NaN               on                on
# 18   ExperimentState NaN              NaN               NaN
# 19   ExperimentState NaN               on                on
# 20   ExperimentState NaN              NaN               NaN
# 21   ExperimentState NaN               on                on
# 22   ExperimentState NaN              NaN               NaN
# 23   ExperimentState NaN               on                on
# 24   ExperimentState NaN              NaN               NaN
# 25   ExperimentState NaN               on                on
# 26   ExperimentState NaN              NaN               NaN
# 27   ExperimentState NaN               on                on
# 28   ExperimentState NaN              NaN               NaN
# 29   ExperimentState NaN               on                on
# 30   ExperimentState NaN              NaN               NaN
#
#    are-windows-opened front-wall                item-used notes  \
# 0                 NaN        NaN                      NaN   NaN
# 1                  on        1.5      φαρμακευτική λοτιόν
# 2                 NaN        NaN                      NaN   NaN
# 3                  on        1.5      Φαρμακευτικό αλκοόλ
# 4                 NaN        NaN                      NaN   NaN
# 5                  on        1.5      Φαρμακευτικό αλκοόλ
# 6                 NaN        NaN                      NaN   NaN
# 7                  on        1.5      Φαρμακευτικό αλκοόλ
# 8                 NaN        NaN                      NaN   NaN
# 9                  on        1.5      Φαρμακευτικό αλκοόλ
# 10                NaN        NaN                      NaN   NaN
# 11                 on        1.5      Φαρμακευτικό αλκοόλ
# 12                NaN        NaN                      NaN   NaN
# 13                 on        1.5      Φαρμακευτικό αλκοόλ
# 14                NaN        NaN                      NaN   NaN
# 15                 on        1.5      Φαρμακευτικό αλκοόλ
# 16                NaN        NaN                      NaN   NaN
# 17                 on        1.5      Φαρμακευτικό αλκοόλ
# 18                NaN        NaN                      NaN   NaN
# 19                 on        1.5  Φαρμακευτικό αλκοόλ 95%
# 20                NaN        NaN                      NaN   NaN
# 21                 on        1.5  Φαρμακευτικό αλκοόλ 95%
# 22                NaN        NaN                      NaN   NaN
# 23                 on        1.5  Φαρμακευτικό αλκοόλ 95%
# 24                NaN        NaN                      NaN   NaN
# 25                 on        1.5  Φαρμακευτικό αλκοόλ 95%
# 26                NaN        NaN                      NaN   NaN
# 27                 on        1.5  Φαρμακευτικό αλκοόλ 95%
# 28                NaN        NaN                      NaN   NaN
# 29                 on        1.5  φαρμακευτική λοτιόν 93%
# 30                NaN        NaN                      NaN   NaN
#
#    pollutant-type                                      quantity-used    room  \
# 0             NaN                                                NaN     NaN
# 1             VOC                           δύο κουταλιές της σούπας  Σαλόνι
# 2             NaN                                                NaN     NaN
# 3             VOC                          τρεις κουταλιά της σούπας  Σαλόνι
# 4             NaN                                                NaN     NaN
# 5             VOC                          τρεις κουταλιά της σούπας  Σαλόνι
# 6             NaN                                                NaN     NaN
# 7             VOC                          τρεις κουταλιά της σούπας  Σαλόνι
# 8             NaN                                                NaN     NaN
# 9             VOC                          τρεις κουταλιά της σούπας  Σαλόνι
# 10            NaN                                                NaN     NaN
# 11            VOC  τρεις κουταλιά της σούπας+ ότι δεν έχει εξατμι...  Σαλόνι
# 12            NaN                                                NaN     NaN
# 13            VOC  τρεις κουταλιά της σούπας+ ότι δεν έχει εξατμι...  Σαλόνι
# 14            NaN                                                NaN     NaN
# 15            VOC  τρεις κουταλιά της σούπας+ ότι δεν έχει εξατμι...  Σαλόνι
# 16            NaN                                                NaN     NaN
# 17            VOC                            μία κουταλιά της σούπας  Σαλόνι
# 18            NaN                                                NaN     NaN
# 19            VOC                            μία κουταλιά της σούπας  Σαλόνι
# 20            NaN                                                NaN     NaN
# 21            VOC                                      13 ml περιπου  σαλονι
# 22            NaN                                                NaN     NaN
# 23            VOC                                              17 ml  Σαλόνι
# 24            NaN                                                NaN     NaN
# 25            VOC                                              10 ml  Σαλόνι
# 26            NaN                                                NaN     NaN
# 27            VOC                                                 13  Σαλόνι
# 28            NaN                                                NaN     NaN
# 29            VOC                                              35 ml  Σαλόνι
# 30            NaN                                                NaN     NaN
#
#    side-right-wall       epoch_ms                  timestamp_local
# 0              NaN  1749658855857 2025-06-11 19:20:55.857000+03:00
# 1              1.7  1749659387774 2025-06-11 19:29:47.774000+03:00
# 2              NaN  1749661557509 2025-06-11 20:05:57.509000+03:00
# 3              1.7  1749662349567 2025-06-11 20:19:09.567000+03:00
# 4              NaN  1749664476491 2025-06-11 20:54:36.491000+03:00
# 5              1.7  1749665195504 2025-06-11 21:06:35.504000+03:00
# 6              NaN  1749667267330 2025-06-11 21:41:07.330000+03:00
# 7              1.7  1749668098365 2025-06-11 21:54:58.365000+03:00
# 8              NaN  1749670295490 2025-06-11 22:31:35.490000+03:00
# 9              1.7  1749671423708 2025-06-11 22:50:23.708000+03:00
# 10             NaN  1749673627254 2025-06-11 23:27:07.254000+03:00
# 11             1.7  1749674365114 2025-06-11 23:39:25.114000+03:00
# 12             NaN  1749676339982 2025-06-12 00:12:19.982000+03:00
# 13             1.7  1749677242338 2025-06-12 00:27:22.338000+03:00
# 14             NaN  1749679308742 2025-06-12 01:01:48.742000+03:00
# 15             1.5  1749680588949 2025-06-12 01:23:08.949000+03:00
# 16             NaN  1749682858533 2025-06-12 02:00:58.533000+03:00
# 17             1.5  1749683936838 2025-06-12 02:18:56.838000+03:00
# 18             NaN  1749743543693 2025-06-12 18:52:23.693000+03:00
# 19             1.5  1749744863788 2025-06-12 19:14:23.788000+03:00
# 20             NaN  1749748880682 2025-06-12 20:21:20.682000+03:00
# 21             1.5  1749750294045 2025-06-12 20:44:54.045000+03:00
# 22             NaN  1749752804880 2025-06-12 21:26:44.880000+03:00
# 23             1.7  1749754315351 2025-06-12 21:51:55.351000+03:00
# 24             NaN  1749756656094 2025-06-12 22:30:56.094000+03:00
# 25             1.7  1749759362051 2025-06-12 23:16:02.051000+03:00
# 26             NaN  1749761724467 2025-06-12 23:55:24.467000+03:00
# 27             1.7  1749762628817 2025-06-13 00:10:28.817000+03:00
# 28             NaN  1749764985584 2025-06-13 00:49:45.584000+03:00
# 29             1.7  1749765803734 2025-06-13 01:03:23.734000+03:00
# 30             NaN  1749767842431 2025-06-13 01:37:22.431000+03:00

# %%
start_time = df_userInputData.loc[12,"epoch_ms"]
end_time   = df_userInputData.loc[30,"epoch_ms"] 

url = "http://192.168.43.25:8080/timeSeriesEndpoints/getTimeSeriesData?start=" + str(start_time) + '&end=' +str(end_time)
print(url)
df_timeSeriesDuringExperiments = pd.DataFrame.from_dict(getData(url))
# Out:
# http://192.168.43.25:8080/timeSeriesEndpoints/getTimeSeriesData?start=1749676339982&end=1749767842431
# Received 123457 records.

# %%
df_timeSeriesDuringExperiments
# Out:
#         CCS811:30minutesPassed  CCS811:RawResistance  CCS811:TVOC  \
# 0                          1.0                 723.0       3136.0
# 1                          NaN                   NaN          NaN
# 2                          1.0                 721.0       3155.0
# 3                          1.0                 718.0       3181.0
# 4                          NaN                   NaN          NaN
# ...                        ...                   ...          ...
# 123452                     NaN                   NaN          NaN
# 123453                     1.0                 535.0       5557.0
# 123454                     1.0                 538.0       5513.0
# 123455                     NaN                   NaN          NaN
# 123456                     1.0                 540.0       5469.0
#
#         CCS811:eCO2  Id  Sensor                                   _id  \
# 0            3135.0   0  CCS811  {'$oid': '6849f13403a598ff63a7abdc'}
# 1               NaN   2  BME680  {'$oid': '6849f13403a598ff63a7abdf'}
# 2            3141.0   0  CCS811  {'$oid': '6849f13503a598ff63a7abe2'}
# 3            3156.0   0  CCS811  {'$oid': '6849f13603a598ff63a7abe5'}
# 4               NaN   1  BME680  {'$oid': '6849f13603a598ff63a7abe8'}
# ...             ...  ..     ...                                   ...
# 123452          NaN   2  BME680  {'$oid': '684b569fb6e12fa45686188d'}
# 123453       4272.0   0  CCS811  {'$oid': '684b569fb6e12fa456861890'}
# 123454       4248.0   0  CCS811  {'$oid': '684b56a1b6e12fa456861893'}
# 123455          NaN   1  BME680  {'$oid': '684b56a1b6e12fa456861896'}
# 123456       4232.0   0  CCS811  {'$oid': '684b56a1b6e12fa456861899'}
#
#                        timestamp  BME680:breathVocEquivalent  \
# 0       2025-06-11T21:12:20.429Z                         NaN
# 1       2025-06-11T21:12:20.449Z                    0.717818
# 2       2025-06-11T21:12:21.055Z                         NaN
# 3       2025-06-11T21:12:22.077Z                         NaN
# 4       2025-06-11T21:12:22.981Z                    0.616748
# ...                          ...                         ...
# 123452  2025-06-12T22:37:19.775Z                    1.190076
# 123453  2025-06-12T22:37:19.962Z                         NaN
# 123454  2025-06-12T22:37:21.595Z                         NaN
# 123455  2025-06-12T22:37:21.720Z                    0.659822
# 123456  2025-06-12T22:37:21.973Z                         NaN
#
#         BME680:co2Equivalent  BME680:gasPercentage  BME680:gasResistance  \
# 0                        NaN                   NaN                   NaN
# 1                   663.7906              6.133245             186824.50
# 2                        NaN                   NaN                   NaN
# 3                        NaN                   NaN                   NaN
# 4                   637.0197             10.792370              67856.85
# ...                      ...                   ...                   ...
# 123452              882.4377              7.141284             177617.50
# 123453                   NaN                   NaN                   NaN
# 123454                   NaN                   NaN                   NaN
# 123455              648.9291              5.420489              70156.30
# 123456                   NaN                   NaN                   NaN
#
#         BME680:humidity  BME680:iaq  BME680:iaqAccuracy  BME680:staticIaq  \
# 0                   NaN         NaN                 NaN               NaN
# 1              62.92079    54.33012                 3.0          65.94767
# 2                   NaN         NaN                 NaN               NaN
# 3                   NaN         NaN                 NaN               NaN
# 4              59.62783    57.57892                 3.0          59.25492
# ...                 ...         ...                 ...               ...
# 123452         64.45795    74.31653                 3.0          88.24377
# 123453              NaN         NaN                 NaN               NaN
# 123454              NaN         NaN                 NaN               NaN
# 123455         59.56725    67.29487                 3.0          62.23227
# 123456              NaN         NaN                 NaN               NaN
#
#         BME680:temperature
# 0                      NaN
# 1                 25.67378
# 2                      NaN
# 3                      NaN
# 4                 26.36054
# ...                    ...
# 123452            25.74519
# 123453                 NaN
# 123454                 NaN
# 123455            26.90834
# 123456                 NaN
#
# [123457 rows x 17 columns]
