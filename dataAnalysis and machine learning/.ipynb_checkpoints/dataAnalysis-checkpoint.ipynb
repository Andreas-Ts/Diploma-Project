# %%
#the import packages
import requests
import pandas as pd
from pandas import json_normalize
import requests
import os
from pathlib import Path

import json
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
base_url = "http://personal-laptop.local:8080/"

# %%
script_dir = Path().resolve().parent

def create_url(base_url,first_part_endpoint,second_part_endpoint):
    return base_url + first_part_endpoint + second_part_endpoint
def getData(url):
    response = requests.get(url)

    # Check response status
    if response.status_code == 200:
        data = response.json()
        print(f"Received {len(data)} records.")
        return data
    else:
        print(f"Error: {response.status_code}")

def saveDataIntoDataFolder(url,data_file_name):
    data_folder = script_dir / 'dataAnalysis and machine learning'/'data'
    print(data_folder)
    data_folder.mkdir(exist_ok=True)
    
    file_path = data_folder / (data_file_name + ".json")
    
    data = getData(url)
    
    if data:
        with open(file_path, 'w') as file:
            json.dump(data, file)
        print(f"Data saved to {file_path}")
    else:
        print("No data to save.")


def loadDataFromFile(file_name):
    data_folder = script_dir / 'dataAnalysis and machine learning'/'data'
    print(data_folder)
    data_folder.mkdir(exist_ok=True)
    
    file_path = data_folder / (file_name + ".json")
    
    if file_path.exists():
        df = pd.read_json(file_path)
        print(f"Loaded {len(df)} records from {file_path}")
        return df
    else:
        print(f"File {file_path} does not exist.")
        return None

# %%
first_part_endpoint = "dataAnalysisEndpoints/"
second_part_endpoint = "getAllUserInputsExperimentState"        

url = create_url(base_url,first_part_endpoint,second_part_endpoint)


saveDataIntoDataFolder(url,"UserInputs")
# Out:
# /home/bob/Documents/Diploma project code/Diploma-Project/dataAnalysis and machine learning/data
# Received 271 records.
# Data saved to /home/bob/Documents/Diploma project code/Diploma-Project/dataAnalysis and machine learning/data/UserInputs.json

# %%
saveDataIntoDataFolder(url,"UserInputs")
# Out:
# /home/bob/Documents/Diploma project code/Diploma-Project/dataAnalysis and machine learning/data
# Received 271 records.
# Data saved to /home/bob/Documents/Diploma project code/Diploma-Project/dataAnalysis and machine learning/data/UserInputs.json

# %%
df_userInputData = loadDataFromFile("UserInputs")
# Out:
# /home/bob/Documents/Diploma project code/Diploma-Project/dataAnalysis and machine learning/data
# Loaded 271 records from /home/bob/Documents/Diploma project code/Diploma-Project/dataAnalysis and machine learning/data/UserInputs.json

# %%
df_userInputData
# Out:
#                                       _id           experimentState  \
# 0    {'$oid': '6849ace703a598ff63a65bf8'}        StartingExperiment
# 1    {'$oid': '6849aefb03a598ff63a6667f'}  InsertingSourcePollutant
# 2    {'$oid': '6849b77503a598ff63a68c90'}   RemovingSourcePollutant
# 3    {'$oid': '6849ba8d03a598ff63a69cd3'}  InsertingSourcePollutant
# 4    {'$oid': '6849c2dc03a598ff63a6c299'}   RemovingSourcePollutant
# ..                                    ...                       ...
# 266  {'$oid': '6877f07a3b4cde7d072ccdbb'}   RemovingSourcePollutant
# 267  {'$oid': '6877f2d73b4cde7d072cd2a3'}  InsertingSourcePollutant
# 268  {'$oid': '6877f42b3b4cde7d072cd4c1'}   RemovingSourcePollutant
# 269  {'$oid': '6877f95e3b4cde7d072cd5a9'}  InsertingSourcePollutant
# 270  {'$oid': '6877fa9d3b4cde7d072cd798'}   RemovingSourcePollutant
#
#                     timestamp userInputCategory  \
# 0    {'$date': 1749658855857}   ExperimentState
# 1    {'$date': 1749659387774}   ExperimentState
# 2    {'$date': 1749661557509}   ExperimentState
# 3    {'$date': 1749662349567}   ExperimentState
# 4    {'$date': 1749664476491}   ExperimentState
# ..                        ...               ...
# 266  {'$date': 1752690810389}   ExperimentState
# 267  {'$date': 1752691415915}   ExperimentState
# 268  {'$date': 1752691755988}   ExperimentState
# 269  {'$date': 1752693086374}   ExperimentState
# 270  {'$date': 1752693405962}   ExperimentState
#
#                                                details
# 0                                                  NaN
# 1    {'are-doors-opened': 'on', 'are-people-inside'...
# 2                                                  NaN
# 3    {'are-doors-opened': 'on', 'are-people-inside'...
# 4                                                  NaN
# ..                                                 ...
# 266                                                NaN
# 267  {'are-doors-opened': 'on', 'back-wall': '', 'f...
# 268                                                NaN
# 269  {'are-doors-opened': 'on', 'back-wall': '', 'f...
# 270                                                NaN
#
# [271 rows x 5 columns]

# %%
if 'details' in df_userInputData.columns:
    details_df = df_userInputData["details"].apply(pd.Series)
    
    # Then join with the original DataFrame (drop the nested 'details' if desired)
    df_userInputData = pd.concat([df_userInputData.drop(columns=["details"]), details_df], axis=1)

# %%
df_userInputData.columns
# Out:
# Index([               '_id',    'experimentState',          'timestamp',
#         'userInputCategory',                    0,   'are-doors-opened',
#         'are-people-inside', 'are-windows-opened',         'front-wall',
#                 'item-used',              'notes',     'pollutant-type',
#             'quantity-used',               'room',    'side-right-wall',
#                 'back-wall',     'side-left-wall'],
#       dtype='object')

# %%
if 0 in df_userInputData.columns:
    df_userInputData =df_userInputData.drop(columns=[0])

# %%
# Convert epoch (assumes seconds) to datetime in local time
df_userInputData["epoch_ms"] = df_userInputData["timestamp"].apply(lambda x: x["$date"])
df_userInputData["timestamp_local"] = pd.to_datetime(df_userInputData["epoch_ms"], unit="ms").dt.tz_localize("UTC").dt.tz_convert("Europe/Athens")
df_userInputData.drop(columns = ["timestamp"])
# Out:
#                                       _id           experimentState  \
# 0    {'$oid': '6849ace703a598ff63a65bf8'}        StartingExperiment
# 1    {'$oid': '6849aefb03a598ff63a6667f'}  InsertingSourcePollutant
# 2    {'$oid': '6849b77503a598ff63a68c90'}   RemovingSourcePollutant
# 3    {'$oid': '6849ba8d03a598ff63a69cd3'}  InsertingSourcePollutant
# 4    {'$oid': '6849c2dc03a598ff63a6c299'}   RemovingSourcePollutant
# ..                                    ...                       ...
# 266  {'$oid': '6877f07a3b4cde7d072ccdbb'}   RemovingSourcePollutant
# 267  {'$oid': '6877f2d73b4cde7d072cd2a3'}  InsertingSourcePollutant
# 268  {'$oid': '6877f42b3b4cde7d072cd4c1'}   RemovingSourcePollutant
# 269  {'$oid': '6877f95e3b4cde7d072cd5a9'}  InsertingSourcePollutant
# 270  {'$oid': '6877fa9d3b4cde7d072cd798'}   RemovingSourcePollutant
#
#     userInputCategory are-doors-opened are-people-inside are-windows-opened  \
# 0     ExperimentState              NaN               NaN                NaN
# 1     ExperimentState               on                on                 on
# 2     ExperimentState              NaN               NaN                NaN
# 3     ExperimentState               on                on                 on
# 4     ExperimentState              NaN               NaN                NaN
# ..                ...              ...               ...                ...
# 266   ExperimentState              NaN               NaN                NaN
# 267   ExperimentState               on               NaN                NaN
# 268   ExperimentState              NaN               NaN                NaN
# 269   ExperimentState               on               NaN                NaN
# 270   ExperimentState              NaN               NaN                NaN
#
#     front-wall                item-used notes pollutant-type  \
# 0          NaN                      NaN   NaN            NaN
# 1          1.5      φαρμακευτική λοτιόν                  VOC
# 2          NaN                      NaN   NaN            NaN
# 3          1.5      Φαρμακευτικό αλκοόλ                  VOC
# 4          NaN                      NaN   NaN            NaN
# ..         ...                      ...   ...            ...
# 266        NaN                      NaN   NaN            NaN
# 267        0.4  Φαρμακευτικό αλκοόλ 95%                  VOC
# 268        NaN                      NaN   NaN            NaN
# 269        0.4  Φαρμακευτικό αλκοόλ 95%                  VOC
# 270        NaN                      NaN   NaN            NaN
#
#                  quantity-used  \
# 0                          NaN
# 1     δύο κουταλιές της σούπας
# 2                          NaN
# 3    τρεις κουταλιά της σούπας
# 4                          NaN
# ..                         ...
# 266                        NaN
# 267                      30 ml
# 268                        NaN
# 269                      30 ml
# 270                        NaN
#
#                                                 room side-right-wall  \
# 0                                                NaN             NaN
# 1                                             Σαλόνι             1.7
# 2                                                NaN             NaN
# 3                                             Σαλόνι             1.7
# 4                                                NaN             NaN
# ..                                               ...             ...
# 266                                              NaN             NaN
# 267  Κρεβατοκάμαρα id:1 Μ0.95 Α0.85 id:2 Μ0.95 Α1.55
# 268                                              NaN             NaN
# 269  Κρεβατοκάμαρα id:1 Μ0.95 Α0.85 id:2 Μ0.95 Α1.55
# 270                                              NaN             NaN
#
#     back-wall side-left-wall       epoch_ms                  timestamp_local
# 0         NaN            NaN  1749658855857 2025-06-11 19:20:55.857000+03:00
# 1         NaN            NaN  1749659387774 2025-06-11 19:29:47.774000+03:00
# 2         NaN            NaN  1749661557509 2025-06-11 20:05:57.509000+03:00
# 3         NaN            NaN  1749662349567 2025-06-11 20:19:09.567000+03:00
# 4         NaN            NaN  1749664476491 2025-06-11 20:54:36.491000+03:00
# ..        ...            ...            ...                              ...
# 266       NaN            NaN  1752690810389 2025-07-16 21:33:30.389000+03:00
# 267                     1.05  1752691415915 2025-07-16 21:43:35.915000+03:00
# 268       NaN            NaN  1752691755988 2025-07-16 21:49:15.988000+03:00
# 269                     1.15  1752693086374 2025-07-16 22:11:26.374000+03:00
# 270       NaN            NaN  1752693405962 2025-07-16 22:16:45.962000+03:00
#
# [271 rows x 17 columns]

# %%
dimensions = ['front-wall','side-right-wall','back-wall','side-left-wall']
for dimension in dimensions:
    df_userInputData[dimension] = pd.to_numeric(df_userInputData[dimension], errors='coerce')

# %%
condition = df_userInputData["room"] == "Κρεβατοκάμαρα id:1 Μ0.95 Α0.85 id:2 Μ0.95 Α1.55"

# Get the indices of the rows that match the condition
matching_indices = df_userInputData[condition].index

# Add the matching indices and the next row's indices
all_indices = list(matching_indices)

# Add the index of the next row for each match (if it's within bounds)
for idx in matching_indices:
    if idx + 1 < len(df_userInputData):
        all_indices.append(idx + 1)

# Get unique and sorted indices to avoid duplicates or order issues
all_indices = sorted(set(all_indices))

# Filter the dataframe
df_userInputData_smallScale = df_userInputData.loc[all_indices]

# %%
df_userInputData_smallScale = df_userInputData_smallScale.reset_index(drop=True) 
df_userInputData_smallScale
# Out:
#                                       _id           experimentState  \
# 0    {'$oid': '686408456a2505a88d9b0665'}  InsertingSourcePollutant
# 1    {'$oid': '686409746a2505a88d9b087a'}   RemovingSourcePollutant
# 2    {'$oid': '68640eee885e900bf5302e85'}  InsertingSourcePollutant
# 3    {'$oid': '6864103c885e900bf5303149'}   RemovingSourcePollutant
# 4    {'$oid': '6864113e885e900bf530336f'}  InsertingSourcePollutant
# ..                                    ...                       ...
# 173  {'$oid': '6877f07a3b4cde7d072ccdbb'}   RemovingSourcePollutant
# 174  {'$oid': '6877f2d73b4cde7d072cd2a3'}  InsertingSourcePollutant
# 175  {'$oid': '6877f42b3b4cde7d072cd4c1'}   RemovingSourcePollutant
# 176  {'$oid': '6877f95e3b4cde7d072cd5a9'}  InsertingSourcePollutant
# 177  {'$oid': '6877fa9d3b4cde7d072cd798'}   RemovingSourcePollutant
#
#                     timestamp userInputCategory are-doors-opened  \
# 0    {'$date': 1751386181232}   ExperimentState               on
# 1    {'$date': 1751386484742}   ExperimentState              NaN
# 2    {'$date': 1751387886945}   ExperimentState               on
# 3    {'$date': 1751388220517}   ExperimentState              NaN
# 4    {'$date': 1751388478248}   ExperimentState               on
# ..                        ...               ...              ...
# 173  {'$date': 1752690810389}   ExperimentState              NaN
# 174  {'$date': 1752691415915}   ExperimentState               on
# 175  {'$date': 1752691755988}   ExperimentState              NaN
# 176  {'$date': 1752693086374}   ExperimentState               on
# 177  {'$date': 1752693405962}   ExperimentState              NaN
#
#     are-people-inside are-windows-opened  front-wall                item-used  \
# 0                 NaN                NaN        0.95  Φαρμακευτικό αλκοόλ 95%
# 1                 NaN                NaN         NaN                      NaN
# 2                 NaN                NaN        0.95  Φαρμακευτικό αλκοόλ 95%
# 3                 NaN                NaN         NaN                      NaN
# 4                 NaN                NaN        0.95  Φαρμακευτικό αλκοόλ 95%
# ..                ...                ...         ...                      ...
# 173               NaN                NaN         NaN                      NaN
# 174               NaN                NaN        0.40  Φαρμακευτικό αλκοόλ 95%
# 175               NaN                NaN         NaN                      NaN
# 176               NaN                NaN        0.40  Φαρμακευτικό αλκοόλ 95%
# 177               NaN                NaN         NaN                      NaN
#
#     notes pollutant-type quantity-used  \
# 0                    VOC         30 ml
# 1     NaN            NaN           NaN
# 2                    VOC         30 ml
# 3     NaN            NaN           NaN
# 4                    VOC         30 ml
# ..    ...            ...           ...
# 173   NaN            NaN           NaN
# 174                  VOC         30 ml
# 175   NaN            NaN           NaN
# 176                  VOC         30 ml
# 177   NaN            NaN           NaN
#
#                                                 room  side-right-wall  \
# 0    Κρεβατοκάμαρα id:1 Μ0.95 Α0.85 id:2 Μ0.95 Α1.55              NaN
# 1                                                NaN              NaN
# 2    Κρεβατοκάμαρα id:1 Μ0.95 Α0.85 id:2 Μ0.95 Α1.55              NaN
# 3                                                NaN              NaN
# 4    Κρεβατοκάμαρα id:1 Μ0.95 Α0.85 id:2 Μ0.95 Α1.55              NaN
# ..                                               ...              ...
# 173                                              NaN              NaN
# 174  Κρεβατοκάμαρα id:1 Μ0.95 Α0.85 id:2 Μ0.95 Α1.55              NaN
# 175                                              NaN              NaN
# 176  Κρεβατοκάμαρα id:1 Μ0.95 Α0.85 id:2 Μ0.95 Α1.55              NaN
# 177                                              NaN              NaN
#
#      back-wall  side-left-wall       epoch_ms                  timestamp_local
# 0          NaN            0.95  1751386181232 2025-07-01 19:09:41.232000+03:00
# 1          NaN             NaN  1751386484742 2025-07-01 19:14:44.742000+03:00
# 2          NaN            1.05  1751387886945 2025-07-01 19:38:06.945000+03:00
# 3          NaN             NaN  1751388220517 2025-07-01 19:43:40.517000+03:00
# 4          NaN            1.05  1751388478248 2025-07-01 19:47:58.248000+03:00
# ..         ...             ...            ...                              ...
# 173        NaN             NaN  1752690810389 2025-07-16 21:33:30.389000+03:00
# 174        NaN            1.05  1752691415915 2025-07-16 21:43:35.915000+03:00
# 175        NaN             NaN  1752691755988 2025-07-16 21:49:15.988000+03:00
# 176        NaN            1.15  1752693086374 2025-07-16 22:11:26.374000+03:00
# 177        NaN             NaN  1752693405962 2025-07-16 22:16:45.962000+03:00
#
# [178 rows x 18 columns]

# %%
df_userInputData_smallScale.loc[df_userInputData_smallScale['front-wall'] == 0.5, 'front-wall'] = 0.4

# %%
df_unique_position_count = df_userInputData_smallScale.groupby(['front-wall', 'side-right-wall','back-wall','side-left-wall'], dropna=False).size().reset_index(name='count')

# %%
df_unique_position_count
# Out:
#     front-wall  side-right-wall  back-wall  side-left-wall  count
# 0         0.40              NaN        NaN            0.55      1
# 1         0.40              NaN        NaN            0.95      4
# 2         0.40              NaN        NaN            1.05      4
# 3         0.40              NaN        NaN            1.15      4
# 4         0.40              NaN        NaN            1.25      4
# 5         0.40              NaN        NaN            1.35      3
# 6         0.40              NaN        NaN            1.75      2
# 7         0.95              NaN        NaN            0.55      2
# 8         0.95              NaN        NaN            0.95      6
# 9         0.95              NaN        NaN            1.05      6
# 10        0.95              NaN        NaN            1.15      6
# 11        0.95              NaN        NaN            1.25      6
# 12        0.95              NaN        NaN            1.35      6
# 13        0.95              NaN        NaN            1.45      3
# 14        0.95              NaN        NaN            1.75      4
# 15        0.95              NaN        NaN            1.85      1
# 16        1.40              NaN        NaN            0.55      2
# 17        1.40              NaN        NaN            0.95      3
# 18        1.40              NaN        NaN            1.05      5
# 19        1.40              NaN        NaN            1.15      4
# 20        1.40              NaN        NaN            1.25      4
# 21        1.40              NaN        NaN            1.35      4
# 22        1.40              NaN        NaN            1.75      4
# 23        1.40              NaN        NaN             NaN      1
# 24         NaN              NaN        NaN             NaN     89

# %%
print(df_unique_position_count["front-wall"].dtype)
# Out:
# float64

# %%
first_idx = df_userInputData.index[0]
last_idx = df_userInputData.index[-1]
start_time = df_userInputData.loc[first_idx,"epoch_ms"]
end_time   = df_userInputData.loc[last_idx,"epoch_ms"] 
first_part_endpoint = "timeSeriesEndpoints/"
second_part_endpoint = "getTimeSeriesData?start=" + str(start_time) + '&end=' +str(end_time)
file_name="TimeSeries"

# %%
url = create_url(base_url,first_part_endpoint,second_part_endpoint)
saveDataIntoDataFolder(url,file_name)
df_timeSeries = loadDataFromFile(file_name)
# Out:
# /home/bob/Documents/Diploma project code/Diploma-Project/dataAnalysis and machine learning/data
# Received 579511 records.
# Data saved to /home/bob/Documents/Diploma project code/Diploma-Project/dataAnalysis and machine learning/data/TimeSeries.json
# /home/bob/Documents/Diploma project code/Diploma-Project/dataAnalysis and machine learning/data
# Loaded 579511 records from /home/bob/Documents/Diploma project code/Diploma-Project/dataAnalysis and machine learning/data/TimeSeries.json

# %%
df_timeSeries
# Out:
#         CCS811:30minutesPassed  CCS811:RawResistance  CCS811:TVOC  \
# 0                          1.0                 437.0       8145.0
# 1                          NaN                   NaN          NaN
# 2                          1.0                 439.0       8088.0
# 3                          1.0                 440.0       8055.0
# 4                          NaN                   NaN          NaN
# ...                        ...                   ...          ...
# 579506                     NaN                   NaN          NaN
# 579507                     NaN                   NaN          NaN
# 579508                     NaN                   NaN          NaN
# 579509                     NaN                   NaN          NaN
# 579510                     NaN                   NaN          NaN
#
#         CCS811:eCO2  Id  Sensor                                   _id  \
# 0            5464.0   0  CCS811  {'$oid': '6849ace703a598ff63a65bff'}
# 1               NaN   1  BME680  {'$oid': '6849ace703a598ff63a65c00'}
# 2            5438.0   0  CCS811  {'$oid': '6849ace903a598ff63a65c0b'}
# 3            5423.0   0  CCS811  {'$oid': '6849ace903a598ff63a65c0e'}
# 4               NaN   2  BME680  {'$oid': '6849acea03a598ff63a65c11'}
# ...             ...  ..     ...                                   ...
# 579506          NaN   1  BME680  {'$oid': '6877fa973b4cde7d072cd789'}
# 579507          NaN   2  BME680  {'$oid': '6877fa983b4cde7d072cd78c'}
# 579508          NaN   1  BME680  {'$oid': '6877fa9a3b4cde7d072cd78f'}
# 579509          NaN   2  BME680  {'$oid': '6877fa9b3b4cde7d072cd792'}
# 579510          NaN   1  BME680  {'$oid': '6877fa9d3b4cde7d072cd795'}
#
#                               timestamp  BME680:breathVocEquivalent  \
# 0      2025-06-11 16:20:55.952000+00:00                         NaN
# 1      2025-06-11 16:20:55.994000+00:00                    0.769688
# 2      2025-06-11 16:20:57.517000+00:00                         NaN
# 3      2025-06-11 16:20:57.945000+00:00                         NaN
# 4      2025-06-11 16:20:58.059000+00:00                    0.653498
# ...                                 ...                         ...
# 579506        2025-07-16 19:16:39+00:00                    1.972986
# 579507        2025-07-16 19:16:40+00:00                    6.955028
# 579508        2025-07-16 19:16:42+00:00                    1.948035
# 579509        2025-07-16 19:16:43+00:00                    7.145324
# 579510        2025-07-16 19:16:45+00:00                    1.933985
#
#         BME680:co2Equivalent  ...  BME680:staticIaq  BME680:temperature  \
# 0                        NaN  ...               NaN                 NaN
# 1                   690.2465  ...          69.02464            29.64483
# 2                        NaN  ...               NaN                 NaN
# 3                        NaN  ...               NaN                 NaN
# 4                   647.2300  ...          61.80751            29.43039
# ...                      ...  ...               ...                 ...
# 579506             1105.3880  ...         110.53880            33.53823
# 579507             1661.0380  ...         166.10380            33.82477
# 579508             1099.7750  ...         109.97750            33.53314
# 579509             1672.9420  ...         167.29420            33.82222
# 579510             1096.5830  ...         109.65830            33.53823
#
#         BME680:breathVocEquivalentAccuracy  BME680:co2EquivalentAccuracy  \
# 0                                      NaN                           NaN
# 1                                      NaN                           NaN
# 2                                      NaN                           NaN
# 3                                      NaN                           NaN
# 4                                      NaN                           NaN
# ...                                    ...                           ...
# 579506                                 0.0                           0.0
# 579507                                 0.0                           0.0
# 579508                                 0.0                           0.0
# 579509                                 0.0                           0.0
# 579510                                 0.0                           0.0
#
#         BME680:gasPercentageAccuracy  BME680:pressure  BME680:rawHumidity  \
# 0                                NaN              NaN                 NaN
# 1                                NaN              NaN                 NaN
# 2                                NaN              NaN                 NaN
# 3                                NaN              NaN                 NaN
# 4                                NaN              NaN                 NaN
# ...                              ...              ...                 ...
# 579506                           0.0         100807.9            41.65589
# 579507                           0.0         100784.7            40.91597
# 579508                           0.0         100807.7            41.66766
# 579509                           0.0         100782.8            40.92166
# 579510                           0.0         100807.9            41.68680
#
#         BME680:rawTemperature  BME680:runInStatus  BME680:stabStatus
# 0                         NaN                 NaN                NaN
# 1                         NaN                 NaN                NaN
# 2                         NaN                 NaN                NaN
# 3                         NaN                 NaN                NaN
# 4                         NaN                 NaN                NaN
# ...                       ...                 ...                ...
# 579506               33.64655                 0.0                1.0
# 579507               33.93308                 0.0                1.0
# 579508               33.64145                 0.0                1.0
# 579509               33.93053                 0.0                1.0
# 579510               33.64655                 0.0                1.0
#
# [579511 rows x 25 columns]

# %%
# 1. Select only the needed column
df_timeSeriesExperiments = df_timeSeries[['timestamp', 'Id', 'BME680:breathVocEquivalent']]

# %%
# 2. Convert `timestamp` (UTC) to Europe/Athens tz-aware datetime
df_timeSeriesExperiments['timestamp'] = (
    pd.to_datetime(df_timeSeriesExperiments['timestamp'], utc=True)
      .dt.tz_convert('Europe/Athens')
)
# 3. Create the two “Id=…:” columns

df_timeSeriesExperiments['Id=1:BME680:breathVocEquivalent'] = np.where(
    df_timeSeriesExperiments['Id'] == 1, df_timeSeriesExperiments['BME680:breathVocEquivalent'], np.nan
)
df_timeSeriesExperiments['Id=2:BME680:breathVocEquivalent'] = np.where(
    df_timeSeriesExperiments['Id'] == 2, df_timeSeriesExperiments['BME680:breathVocEquivalent'], np.nan
)

# 4. Set timestamp as the row index
df_timeSeriesExperiments.set_index('timestamp', inplace=True)

# 5. Drop the old Id+raw measurement columns
df_timeSeriesExperiments = df_timeSeriesExperiments.drop(
    columns=['Id', 'BME680:breathVocEquivalent']
)

# Inspect result
df_timeSeriesExperiments.head()
df_timeSeriesExperiments
# Out:
# /tmp/ipykernel_5082/1475842332.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_timeSeriesExperiments['timestamp'] = (
# /tmp/ipykernel_5082/1475842332.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_timeSeriesExperiments['Id=1:BME680:breathVocEquivalent'] = np.where(
# /tmp/ipykernel_5082/1475842332.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_timeSeriesExperiments['Id=2:BME680:breathVocEquivalent'] = np.where(
#                                   Id=1:BME680:breathVocEquivalent  \
# timestamp
# 2025-06-11 19:20:55.952000+03:00                              NaN
# 2025-06-11 19:20:55.994000+03:00                         0.769688
# 2025-06-11 19:20:57.517000+03:00                              NaN
# 2025-06-11 19:20:57.945000+03:00                              NaN
# 2025-06-11 19:20:58.059000+03:00                              NaN
# ...                                                           ...
# 2025-07-16 22:16:39+03:00                                1.972986
# 2025-07-16 22:16:40+03:00                                     NaN
# 2025-07-16 22:16:42+03:00                                1.948035
# 2025-07-16 22:16:43+03:00                                     NaN
# 2025-07-16 22:16:45+03:00                                1.933985
#
#                                   Id=2:BME680:breathVocEquivalent
# timestamp
# 2025-06-11 19:20:55.952000+03:00                              NaN
# 2025-06-11 19:20:55.994000+03:00                              NaN
# 2025-06-11 19:20:57.517000+03:00                              NaN
# 2025-06-11 19:20:57.945000+03:00                              NaN
# 2025-06-11 19:20:58.059000+03:00                         0.653498
# ...                                                           ...
# 2025-07-16 22:16:39+03:00                                     NaN
# 2025-07-16 22:16:40+03:00                                6.955028
# 2025-07-16 22:16:42+03:00                                     NaN
# 2025-07-16 22:16:43+03:00                                7.145324
# 2025-07-16 22:16:45+03:00                                     NaN
#
# [579511 rows x 2 columns]

# %%
df_timeSeriesExperiments
# Out:
#                                   Id=1:BME680:breathVocEquivalent  \
# timestamp
# 2025-06-11 19:20:55.952000+03:00                              NaN
# 2025-06-11 19:20:55.994000+03:00                         0.769688
# 2025-06-11 19:20:57.517000+03:00                              NaN
# 2025-06-11 19:20:57.945000+03:00                              NaN
# 2025-06-11 19:20:58.059000+03:00                              NaN
# ...                                                           ...
# 2025-07-16 22:16:39+03:00                                1.972986
# 2025-07-16 22:16:40+03:00                                     NaN
# 2025-07-16 22:16:42+03:00                                1.948035
# 2025-07-16 22:16:43+03:00                                     NaN
# 2025-07-16 22:16:45+03:00                                1.933985
#
#                                   Id=2:BME680:breathVocEquivalent
# timestamp
# 2025-06-11 19:20:55.952000+03:00                              NaN
# 2025-06-11 19:20:55.994000+03:00                              NaN
# 2025-06-11 19:20:57.517000+03:00                              NaN
# 2025-06-11 19:20:57.945000+03:00                              NaN
# 2025-06-11 19:20:58.059000+03:00                         0.653498
# ...                                                           ...
# 2025-07-16 22:16:39+03:00                                     NaN
# 2025-07-16 22:16:40+03:00                                6.955028
# 2025-07-16 22:16:42+03:00                                     NaN
# 2025-07-16 22:16:43+03:00                                7.145324
# 2025-07-16 22:16:45+03:00                                     NaN
#
# [579511 rows x 2 columns]

# %%
print(df_timeSeriesExperiments["timestamp"].dtypes)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 print(df_timeSeriesExperiments["timestamp"].dtypes)
#
# File ~/venv/lib/python3.12/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File ~/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'timestamp'

# %%
num_experiments = df_timeSeriesExperiments.shape[0] / 2
fig, axes = plt.subplots(num_experiments, 1, figsize=(14, 2 * num_experiments), sharex=False)
df_userInputData_smallScale


for i in range(0, len(df), 2):
    inserting_row = df_userInputData_smallScale.iloc[i]
    removing_row = df_userInputData_smallScale.iloc[i+1]
    data 
    # RIGHT PLOT: Id=1 and Id=2 for BME680
    sns.lineplot(
        data=inserting_row, 
        x="timestamp",
        y='Id=1:BME680:breathVocEquivalent',
        label="Id=1",
        marker='o'
    )
    sns.lineplot(
        data=inserting_row,
        x="timestamp",
        y='Id=2:BME680:breathVocEquivalent',
        label="Id=2",
        marker='s'
    )
    axes[idx, 0].set_title(f"BME680:breathVocEquivalent at {inserting_row["front-wall"]} and {inserting_row["side-left-wall"]}")
    axes[idx, 0].set_xlabel("Timestamp")
    axes[idx, 0].set_ylabel("VOC")
    axes[idx, 0].legend()

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 2
#       1 num_experiments = df_timeSeriesExperiments.shape[0] / 2
# ----> 2 fig, axes = plt.subplots(num_experiments, 2, figsize=(14, 2 * num_experiments), sharex=False)
#       6 for idx, (start, end) in enumerate(experiment_periods):
#       7     # Slice time series data between start and end
#       8     df_range = df_timeSeriesDuringExperiments_final.loc[start:end]
#
# File ~/venv/lib/python3.12/site-packages/matplotlib/pyplot.py:1778, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1633 """
#    1634 Create a figure and a set of subplots.
#    1635
#    (...)   1775
#    1776 """
#    1777 fig = figure(**fig_kw)
# -> 1778 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1779                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1780                    gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1781                    width_ratios=width_ratios)
#    1782 return fig, axs
#
# File ~/venv/lib/python3.12/site-packages/matplotlib/figure.py:918, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw)
#     914         raise ValueError("'width_ratios' must not be defined both as "
#     915                          "parameter and as key in 'gridspec_kw'")
#     916     gridspec_kw['width_ratios'] = width_ratios
# --> 918 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
#     919 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     920                   subplot_kw=subplot_kw)
#     921 return axs
#
# File ~/venv/lib/python3.12/site-packages/matplotlib/figure.py:1600, in FigureBase.add_gridspec(self, nrows, ncols, **kwargs)
#    1557 """
#    1558 Low-level API for creating a `.GridSpec` that has this figure as a parent.
#    1559
#    (...)   1596
#    1597 """
#    1599 _ = kwargs.pop('figure', None)  # pop in case user has added this...
# -> 1600 gs = GridSpec(nrows=nrows, ncols=ncols, figure=self, **kwargs)
#    1601 return gs
#
# File ~/venv/lib/python3.12/site-packages/matplotlib/gridspec.py:363, in GridSpec.__init__(self, nrows, ncols, figure, left, bottom, right, top, wspace, hspace, width_ratios, height_ratios)
#     360 self.hspace = hspace
#     361 self.figure = figure
# --> 363 super().__init__(nrows, ncols,
#     364                  width_ratios=width_ratios,
#     365                  height_ratios=height_ratios)
#
# File ~/venv/lib/python3.12/site-packages/matplotlib/gridspec.py:48, in GridSpecBase.__init__(self, nrows, ncols, height_ratios, width_ratios)
#      33 """
#      34 Parameters
#      35 ----------
#    (...)     45     If not given, all rows will have the same height.
#      46 """
#      47 if not isinstance(nrows, Integral) or nrows <= 0:
# ---> 48     raise ValueError(
#      49         f"Number of rows must be a positive integer, not {nrows!r}")
#      50 if not isinstance(ncols, Integral) or ncols <= 0:
#      51     raise ValueError(
#      52         f"Number of columns must be a positive integer, not {ncols!r}")
#
# ValueError: Number of rows must be a positive integer, not 285028.0
# Error in callback <function _draw_all_if_interactive at 0x7551f24d9260> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/venv/lib/python3.12/site-packages/matplotlib/pyplot.py:279, in _draw_all_if_interactive()
#     277 def _draw_all_if_interactive() -> None:
#     278     if matplotlib.is_interactive():
# --> 279         draw_all()
#
# File ~/venv/lib/python3.12/site-packages/matplotlib/_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File ~/venv/lib/python3.12/site-packages/matplotlib/backend_bases.py:1891, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1889 if not self._is_idle_drawing:
#    1890     with self._idle_draw_cntx():
# -> 1891         self.draw(*args, **kwargs)
#
# File ~/venv/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:377, in FigureCanvasAgg.draw(self)
#     375 def draw(self):
#     376     # docstring inherited
# --> 377     self.renderer = self.get_renderer()
#     378     self.renderer.clear()
#     379     # Acquire a lock on the shared font cache.
#
# File ~/venv/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:392, in FigureCanvasAgg.get_renderer(self)
#     390 reuse_renderer = (self._lastKey == key)
#     391 if not reuse_renderer:
# --> 392     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     393     self._lastKey = key
#     394 return self.renderer
#
# File ~/venv/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:69, in RendererAgg.__init__(self, width, height, dpi)
#      67 self.width = width
#      68 self.height = height
# ---> 69 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      70 self._filter_renderers = []
#      72 self._update_methods()
#
# ValueError: Image size of 1400x57005600 pixels is too large. It must be less than 2^23 in each direction.
